# %%
import numpy as np
from IPython.display import display
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\PC\Desktop\AI Course - E-Com\files\sport_athletes.csv")
df
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
# 1. 
df.groupby('Sport Type').agg({'Weight(kg)': 'min', 'Height(cm)': 'max', 'Wins': 'max'}).rename(columns={'Weight(kg)': 'max_weight', 'Height(cm)': 'max_height', 'Wins': 'max_wins'})
# Out:
#                  max_weight  max_height  max_wins
# Sport Type
# Basketball               96         216         3
# Cycling                  68         186         5
# Gymnastics               45         160         5
# Soccer                   57         187         3
# Swimming                 58         200         5
# Tennis                   70         188         4
# Track and Field          57         195         6

# %%
# 2. 
df.groupby('Sport Type')['Height(cm)'].nlargest(2)
# Out:
# Sport Type
# Basketball       4     216
#                  3     208
# Cycling          28    186
#                  27    184
# Gymnastics       33    160
#                  34    157
# Soccer           7     187
#                  9     185
# Swimming         15    200
#                  14    196
# Tennis           19    188
#                  16    185
# Track and Field  20    195
#                  21    188
# Name: Height(cm), dtype: int64

# %%
# 3.a. 
df.groupby(['Country', 'Sport Type']).agg({'Weight(kg)': 'max', 'Height(cm)': 'max', 'Wins': 'max'})
# Out:
#                              Weight(kg)  Height(cm)  Wins
# Country     Sport Type
# Argentina   Soccer                   69         170     2
# Australia   Swimming                 85         196     4
# Belgium     Cycling                  72         181     5
# Brazil      Soccer                   72         174     3
# China       Swimming                 90         200     3
# France      Soccer                   80         185     3
# Jamaica     Track and Field          94         195     6
# Netherlands Cycling                  68         175     4
# Portugal    Soccer                   83         187     2
# Romania     Gymnastics               50         155     5
# Serbia      Tennis                   84         188     4
# Slovenia    Cycling                  69         186     3
# Spain       Tennis                   85         185     3
# Switzerland Tennis                   85         185     2
# UK          Cycling                  71         183     4
# ...

# %%
# 3.b. 
df.groupby(['Country', 'Sport Type']).agg({'Weight(kg)': 'max', 'Height(cm)': 'max', 'Wins': 'max'}).loc['USA','Basketball']
# Out:
# Weight(kg)    147
# Height(cm)    216
# Wins            3
# Name: (USA, Basketball), dtype: int64

# %%
# 3.c. 
df.groupby(['Country', 'Sport Type']).agg({'Weight(kg)': 'max', 'Height(cm)': 'max', 'Wins': 'max'}).xs(level='Sport Type', key='Soccer')
# Out:
#            Weight(kg)  Height(cm)  Wins
# Country
# Argentina          69         170     2
# Brazil             72         174     3
# France             80         185     3
# Portugal           83         187     2
# USA                62         168     2

# %%
# 3.d. 
df[df['Sport Type'].isin(['Tennis', 'Soccer'])].groupby('Sport Type').max()
# Out:
#            Country     Athlete Name  Height(cm)  Weight(kg)  Wins Olympic Date
# Sport Type
# Soccer         USA  Zinedine Zidane         187          83     3   25/08/2008
# Tennis         USA  Serena Williams         188          85     4   28/07/2008

# %%
# 3.e. 
df.groupby(['Country', 'Sport Type']).max().swaplevel().sort_index(level=['Sport Type', 'Country'])
# Out:
#                                      Athlete Name  Height(cm)  Weight(kg)  \
# Sport Type      Country
# Basketball      USA              Shaquille O'Neal         216         147
# Cycling         Belgium               Eddy Merckx         181          72
#                 Netherlands  Anna van der Breggen         175          68
#                 Slovenia            Tadej Pogacar         186          69
#                 UK                 Geraint Thomas         183          71
# Gymnastics      Romania            Nadia Comaneci         155          50
#                 USA                  Simone Biles         160          52
# Soccer          Argentina            Lionel Messi         170          69
#                 Brazil                       Pelé         174          72
#                 France            Zinedine Zidane         185          80
#                 Portugal        Cristiano Ronaldo         187          83
# ...

# %%
# 3.f. 
df.agg({'Height(cm)': ['max', 'min', 'mean', 'std'], 'Wins': ['max', 'min', 'mean', 'std']})
# Out:
#       Height(cm)      Wins
# max   216.000000  6.000000
# min   142.000000  1.000000
# mean  181.333333  3.388889
# std    16.568473  1.102666

# %%
# 4. 
new_rows = pd.DataFrame({ 'Country': ['Canada', 'USA'], 'Sport Type': ['Hockey', 'Skiing'],
'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'], 'Height(cm)': [183, 172],
'Weight(kg)': [84, 68], 'Wins': [3, 4], 'Olympic Date': ['01/02/2002', '12/02/2010'] })

pd.concat([df, new_rows])
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
# 5. 
smoking = pd.read_csv(r"C:\Users\PC\Desktop\AI Course - E-Com\files\athletes_smoking.csv")
pd.merge(df, smoking, on='Athlete Name', how='inner')
# Out:
#       Country       Sport Type       Athlete Name  Height(cm)  Weight(kg)  \
# 0         USA       Basketball     Michael Jordan         198          98
# 1         USA       Basketball       LeBron James         206         113
# 2         USA       Basketball        Kobe Bryant         198          96
# 3         USA       Basketball       Kevin Durant         208         109
# 4         USA       Basketball   Shaquille O'Neal         216         147
# 5    Portugal           Soccer  Cristiano Ronaldo         187          83
# 6   Argentina           Soccer       Lionel Messi         170          69
# 7         USA           Soccer      Megan Rapinoe         168          62
# 8   Australia         Swimming         Ian Thorpe         196          85
# 9       Spain           Tennis       Rafael Nadal         185          85
# 10    Jamaica  Track and Field         Usain Bolt         195          94
# 11        USA  Track and Field         Carl Lewis         188          81
# ...

# %%
# 5. 
pd.merge(df, smoking, on='Athlete Name', how='outer')
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Gymnastics           Aly Raisman       160.0
# 1   Netherlands          Cycling  Anna van der Breggen       175.0
# 2           USA  Track and Field          Ashton Eaton       185.0
# 3           USA         Swimming        Caeleb Dressel       191.0
# 4           USA  Track and Field            Carl Lewis       188.0
# 5            UK          Cycling          Chris Froome       180.0
# 6      Portugal           Soccer     Cristiano Ronaldo       187.0
# 7       Belgium          Cycling           Eddy Merckx       181.0
# 8           USA  Track and Field     Florence Griffith       165.0
# 9           USA       Gymnastics         Gabby Douglas       150.0
# 10           UK          Cycling        Geraint Thomas       183.0
# 11    Australia         Swimming            Ian Thorpe       196.0
# 12          USA         Swimming         Katie Ledecky       180.0
# ...
