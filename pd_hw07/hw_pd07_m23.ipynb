# %%
import numpy as py
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\PC\Desktop\AI Course - E-Com\files\Sales_Funnel_CRM.csv")
display(df)
# 1. 
company_per_product = pd.pivot_table(df, index='Company', columns='Product', values='Licenses', aggfunc='sum').fillna(0)
# 2. 
total_sales_per_company = pd.pivot_table(df[['Company', 'Licenses', 'Sale Price']], index='Company', values=['Licenses', 'Sale Price'] ,aggfunc='sum')
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %% [markdown]
# # Questions
# ● Show in a new Dataframe how many licenses sold for each company from each product
#
# ● Show in a new Dataframe for each company what is the total amount of sale price and licences sold
#
# Hint: you don’t need to use the original Dataframe as your pivot table source, you can reduce the
# amount
# of unused columns by creating a Dataframe from just the columns you need and then apply the pivot

# %%
# 1. 
display('Total licenses sold per company and product', company_per_product)
print("-" * 100)
# 2. 
display('The total sales and sale price per company', total_sales_per_company)
# Out:
# 'Total licenses sold per company and product'
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              0.0       150.0     300.0
# ATT                 0.0              0.0       150.0     150.0
# Apple             300.0              0.0         0.0       0.0
# BOBO              150.0              0.0         0.0       0.0
# CVS Health          0.0              0.0         0.0     450.0
# Cisco             300.0            300.0         0.0       0.0
# Exxon Mobile      150.0              0.0         0.0       0.0
# IKEA              300.0              0.0         0.0       0.0
# Microsoft           0.0              0.0         0.0     300.0
# Salesforce        750.0              0.0         0.0       0.0
# Tesla Inc.        300.0              0.0       150.0       0.0
# Walmart           150.0              0.0         0.0       0.0
# ...
